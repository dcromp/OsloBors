# %% [markdown]
# #Chapter 1: Scraping OsloBors stock data
#
# In this chapter we get our first data set from the OsloBors, Scandinavia's only independent stock exchange.
#
# #####The Imports
# Most of the hard work in this chapter and the following chapters is done using Pandas, Pythons "library providing high-performance, easy-to-use data structures and data analysis tools".

# %%
import urllib2
import StringIO
import pandas as pd
from pandas import read_html
import pymongo
from pymongo import MongoClient
import json
from datetime import datetime
from pandas.io.data import DataReader
import numpy as np

# %%
#For visulisations
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#From python 3, dont have to worry about divide with floating numbers
from __future__ import division

# %% [markdown]
# #####MongoDB: Where to save the data?
# When we scrape stock information we want we do not want to have to rescrape it everytime we do some analysis. There are a number of methods to save the data, JSON, CSV, MYSQL, Python Pickle file, but I have decided to use MongoDB.
#
# MongoDB is a NoSQL database that stores information as Key:document pairs. Unlike a CSV file or equivalent, you can run powerful queries agasint MongoDB and make updates without loading and re-saving the entire file everytime.

# %%
#Setup MongoDB
#Switch on my file server then run in bash: mongod --dbpath /Volumes/Data/David_Files/data/db/
client = MongoClient()
db = client.oslo_bors #This is our database name
collectionStocks = db.stocks #stocks is our table (Collection) within the database

# %% [markdown]
# #####Creating a list of tickers
# The first thing we need to know is a list of stock tickers, which we want to scrape data from. The OsloBors provides a list of all active stocks and their tickers in the form of a html table which we can get by following a given url. However, this html table is loaded via javascript, this means we cannot simply extract the html table using an html parser. The reason is because most html parsers, like beautiful soup, typically do not render javascript code. So we us a library selenium to open the url in the firefox browser, which does render javascript code. Then we extract the html from the broswer and use pandas to get extract our table and therefore our ticket list.
#
# The end result should look something like this.
#
# tickers = ['ASC', 'AFG',...,'ZONC']

# %%
#Load the webpage in firefox and extract the content
from selenium import webdriver
browser = webdriver.Firefox()
browser.get('http://www.oslobors.no/markedsaktivitet/#/list/shares/quotelist/ob/all/false')
content = browser.page_source
browser.quit()

#Save the list of tickers
stocks = pd.read_html(content)[0]
tickers = stocks['Ticker'].tolist()

# %% [markdown]
# #####The link to stock data
# The following links leads to statoils (STL) excel sheet containing 5 years worth of stock data. We use this link, replacing STL with each ticker in our ticker list to extract data for all our stocks.

# %%
#The link for the statoil stock excel 5 years
link = 'http://www.oslobors.no/ob/servlets/excel?type=history&columns=DATE%2C+CLOSE_CA%2C+BID_CA%2C+ASK_CA%2C+HIGH_CA%2C+LOW_CA%2C+TURNOVER_TOTAL%2C+VOLUME_TOTAL_CA%2C+TRADES_COUNT%2C+TRADES_COUNT_TOTAL%2C+VWAP&format[DATE]=ddd.mm.YY&format[CLOSE_CA]=%23%2C%23%230.00%23%23%23&format[BID_CA]=%23%2C%23%230.00%23%23&format[ASK_CA]=%23%2C%23%230.00%23%23&format[HIGH_CA]=%23%2C%23%230.00%23%23%23&format[LOW_CA]=%23%2C%23%230.00%23%23%23&format[TURNOVER_TOTAL]=%23%2C%23%230&format[VOLUME_TOTAL_CA]=%23%2C%23%230&format[TRADES_COUNT]=%23%2C%23%230&format[TRADES_COUNT_TOTAL]=%23%2C%23%230&format[VWAP]=%23%2C%23%230.00%23%23%23&header[DATE]=STL&header[CLOSE_CA]=Last&header[BID_CA]=Bid&header[ASK_CA]=Ask&header[HIGH_CA]=High&header[LOW_CA]=Low&header[TURNOVER_TOTAL]=Total%20turnover%20%28NOK%29&header[VOLUME_TOTAL_CA]=Total%20amount%20shares%20volume&header[TRADES_COUNT]=Amount%20off.%20trades&header[TRADES_COUNT_TOTAL]=Amount%20trades%20total&header[VWAP]=VWAP&view=DELAYED&source=feed.ose.quotes.INSTRUMENTS&filter=ITEM_SECTOR%3D%3DsSTL.OSE%26%26DELETED!%3Dn1&stop=now&start=1286402400000&space=DAY&ascending=true&limit=10000000&filename=data.xlsx'

# %% [markdown]
# #####Downloading the stock data
# The following code simply runs a loop over all the tickers in our ticker list, puts them in the statoil URL link and downloads the excel file as a pandas dataframe.

# %%
collectionStocks.remove() #Remove the old data from the MongoDB database

for i in tickers:
    
    print str(i) + " - Scraping"
    
    #Extract the Data from the excel
    ticker = str(i).replace(" ","%20") #Some tickers have spaces in their names ('SAS NOK'), so we replace the space with a %20 to not break the URL
    url = link.replace("STL", ticker) #Swap out statoils ticker for the one in our list
    xld = urllib2.urlopen(url).read()
    xlds = StringIO.StringIO(xld)
    data = pd.read_excel(xlds, "data") #Turn the excel file into a pandas dataframe
    
    data.columns = data.columns.str.replace('.','') #The column names are keys in mongoDB and mongoDB doesnt like '.' in its key names
    
    data.rename(columns = {str(i):'Date'}, inplace=True) #Name the date column to date, it is orginally called after the ticker
    
    data['Ticker'] = str(i) #Add a ticker column
    
    records = json.loads(data.T.to_json(date_format='iso')).values() #Convert dataframe to json, which is a format that can be directly loaded into mongoDB
    
    #Here we check for any errors before saving the data to mongoDB
    if len(records) > 0:
        collectionStocks.insert(records) #Store the data in the mongoDB
        
        print str(i) + " - Added to the database" #Current stock we are scraping
    else:
        print str(i) + " - Not scraped, see comment" #some tickers use OAX and not OSE in its link string, so our statoil link returns empty for these tickers. For now we just ignore them
# Out:
# ASC - Scraping
# ASC - Added to the database
# AFG - Scraping
# AFG - Added to the database
# APCL - Scraping
# APCL - Not scraped, see comment
# AGA - Scraping
# AGA - Added to the database
# AKA - Scraping
# AKA - Added to the database
# AKER - Scraping
# AKER - Added to the database
# AKPS - Scraping
# AKPS - Not scraped, see comment
# AKSO - Scraping
# AKSO - Added to the database
# AKVA - Scraping
# AKVA - Added to the database
# AMSC - Scraping
# AMSC - Added to the database
# APP - Scraping
# APP - Added to the database
# ABT - Scraping
# ABT - Not scraped, see comment
# AQUA - Scraping
# AQUA - Added to the database
# ARCHER - Scraping
# ARCHER - Added to the database
# AFK - Scraping
# AFK - Added to the database
# ASETEK - Scraping
# ASETEK - Added to the database
# ATEA - Scraping
# ATEA - Added to the database
# ATLA NOK - Scraping
# ATLA NOK - Added to the database
# AURLPG - Scraping
# AURLPG - Not scraped, see comment
# AUSS - Scraping
# AUSS - Added to the database
# AVANCE - Scraping
# AVANCE - Added to the database
# AVM - Scraping
# AVM - Added to the database
# AWDR - Scraping
# AWDR - Not scraped, see comment
# ALNG - Scraping
# ALNG - Not scraped, see comment
# BXPL - Scraping
# BXPL - Not scraped, see comment
# BAKKA - Scraping
# BAKKA - Added to the database
# BEL - Scraping
# BEL - Added to the database
# BERGEN - Scraping
# BERGEN - Added to the database
# BIONOR - Scraping
# BIONOR - Added to the database
# BIOTEC - Scraping
# BIOTEC - Added to the database
# BIRD - Scraping
# BIRD - Added to the database
# BON - Scraping
# BON - Added to the database
# BOR - Scraping
# BOR - Added to the database
# BRG - Scraping
# BRG - Added to the database
# BOUVET - Scraping
# BOUVET - Added to the database
# BWLPG - Scraping
# BWLPG - Added to the database
# BWO - Scraping
# BWO - Added to the database
# BMA - Scraping
# BMA - Added to the database
# COV - Scraping
# COV - Added to the database
# CXENSE - Scraping
# CXENSE - Not scraped, see comment
# DAT - Scraping
# DAT - Added to the database
# DESSC - Scraping
# DESSC - Added to the database
# DETNOR - Scraping
# DETNOR - Added to the database
# DNB - Scraping
# DNB - Added to the database
# DNO - Scraping
# DNO - Added to the database
# DOF - Scraping
# DOF - Added to the database
# DOLP - Scraping
# DOLP - Added to the database
# EAM - Scraping
# EAM - Not scraped, see comment
# EIOF - Scraping
# EIOF - Added to the database
# EKO - Scraping
# EKO - Added to the database
# EMGS - Scraping
# EMGS - Added to the database
# EMAS - Scraping
# EMAS - Added to the database
# ENTRA - Scraping
# ENTRA - Added to the database
# EQO - Scraping
# EQO - Not scraped, see comment
# EPR - Scraping
# EPR - Added to the database
# EVRY - Scraping
# EVRY - Added to the database
# FAR - Scraping
# FAR - Added to the database
# FLNG - Scraping
# FLNG - Not scraped, see comment
# FOE - Scraping
# FOE - Added to the database
# FRO - Scraping
# FRO - Added to the database
# FUNCOM - Scraping
# FUNCOM - Added to the database
# GIG - Scraping
# GIG - Added to the database
# GRO - Scraping
# GRO - Added to the database
# RISH - Scraping
# RISH - Added to the database
# GJF - Scraping
# GJF - Added to the database
# GOGL - Scraping
# GOGL - Added to the database
# GOD - Scraping
# GOD - Added to the database
# GSF - Scraping
# GSF - Added to the database
# GYL - Scraping
# GYL - Added to the database
# HNA - Scraping
# HNA - Added to the database
# HNB - Scraping
# HNB - Added to the database
# HFISK - Scraping
# HFISK - Added to the database
# HAVI - Scraping
# HAVI - Added to the database
# HYARD - Scraping
# HYARD - Added to the database
# HEX - Scraping
# HEX - Added to the database
# HBC - Scraping
# HBC - Not scraped, see comment
# HUGO - Scraping
# HUGO - Not scraped, see comment
# HLNG - Scraping
# HLNG - Added to the database
# IMSK - Scraping
# IMSK - Added to the database
# IDEX - Scraping
# IDEX - Added to the database
# IOX - Scraping
# IOX - Added to the database
# ITX - Scraping
# ITX - Added to the database
# ITE - Scraping
# ITE - Added to the database
# JIN - Scraping
# JIN - Added to the database
# KIT - Scraping
# KIT - Added to the database
# KOA - Scraping
# KOA - Added to the database
# KOG - Scraping
# KOG - Added to the database
# KVAER - Scraping
# KVAER - Added to the database
# LSG - Scraping
# LSG - Added to the database
# LINK - Scraping
# LINK - Not scraped, see comment
# MSEIS - Scraping
# MSEIS - Not scraped, see comment
# MHG - Scraping
# MHG - Added to the database
# MEDI - Scraping
# MEDI - Added to the database
# MCG - Scraping
# MCG - Not scraped, see comment
# MULTI - Scraping
# MULTI - Added to the database
# NAPA - Scraping
# NAPA - Added to the database
# NATTO - Scraping
# NATTO - Not scraped, see comment
# NAVA - Scraping
# NAVA - Added to the database
# NEL - Scraping
# NEL - Added to the database
# NEXT - Scraping
# NEXT - Not scraped, see comment
# NGT - Scraping
# NGT - Added to the database
# NMG - Scraping
# NMG - Added to the database
# NOFIN - Scraping
# NOFIN - Not scraped, see comment
# NOM - Scraping
# NOM - Not scraped, see comment
# NANO - Scraping
# NANO - Added to the database
# NOD - Scraping
# NOD - Added to the database
# NHY - Scraping
# NHY - Added to the database
# NSG - Scraping
# NSG - Added to the database
# NORTH - Scraping
# NORTH - Not scraped, see comment
# NRS - Scraping
# NRS - Added to the database
# NAS - Scraping
# NAS - Added to the database
# NOR - Scraping
# NOR - Added to the database
# NPRO - Scraping
# NPRO - Added to the database
# NRC - Scraping
# NRC - Added to the database
# NTS - Scraping
# NTS - Added to the database
# OCY - Scraping
# OCY - Added to the database
# OTS - Scraping
# OTS - Added to the database
# ODL - Scraping
# ODL - Added to the database
# ODF - Scraping
# ODF - Added to the database
# ODFB - Scraping
# ODFB - Added to the database
# OLT - Scraping
# OLT - Added to the database
# OPERA - Scraping
# OPERA - Added to the database
# ORK - Scraping
# ORK - Added to the database
# PEN - Scraping
# PEN - Added to the database
# PCIB - Scraping
# PCIB - Not scraped, see comment
# PGS - Scraping
# PGS - Added to the database
# PDR - Scraping
# PDR - Added to the database
# PHO - Scraping
# PHO - Added to the database
# PPG PREF - Scraping
# PPG PREF - Not scraped, see comment
# PLCS - Scraping
# PLCS - Added to the database
# POL - Scraping
# POL - Added to the database
# PRS - Scraping
# PRS - Added to the database
# PROTCT - Scraping
# PROTCT - Added to the database
# QFR - Scraping
# QFR - Added to the database
# QEC - Scraping
# QEC - Added to the database
# RAKP - Scraping
# RAKP - Added to the database
# REACH - Scraping
# REACH - Added to the database
# REC - Scraping
# REC - Added to the database
# REM - Scraping
# REM - Not scraped, see comment
# RENO - Scraping
# RENO - Added to the database
# ROM - Scraping
# ROM - Not scraped, see comment
# RCL - Scraping
# RCL - Added to the database
# SDSD - Scraping
# SDSD - Not scraped, see comment
# SAGA - Scraping
# SAGA - Not scraped, see comment
# SALM - Scraping
# SALM - Added to the database
# SAS NOK - Scraping
# SAS NOK - Added to the database
# SCI - Scraping
# SCI - Added to the database
# SSHIP - Scraping
# SSHIP - Not scraped, see comment
# SSO - Scraping
# SSO - Added to the database
# SCHA - Scraping
# SCHA - Added to the database
# SCHB - Scraping
# SCHB - Added to the database
# SBX - Scraping
# SBX - Added to the database
# SDRL - Scraping
# SDRL - Added to the database
# SBO - Scraping
# SBO - Added to the database
# SENDEX - Scraping
# SENDEX - Not scraped, see comment
# SER - Scraping
# SER - Not scraped, see comment
# SEVDR - Scraping
# SEVDR - Added to the database
# SEVAN - Scraping
# SEVAN - Added to the database
# SIOFF - Scraping
# SIOFF - Added to the database
# SSI - Scraping
# SSI - Added to the database
# SKI - Scraping
# SKI - Added to the database
# SOFF - Scraping
# SOFF - Added to the database
# SOLV - Scraping
# SOLV - Added to the database
# SONG - Scraping
# SONG - Added to the database
# SRBANK - Scraping
# SRBANK - Added to the database
# SPU - Scraping
# SPU - Added to the database
# STL - Scraping
# STL - Added to the database
# SNI - Scraping
# SNI - Added to the database
# STB - Scraping
# STB - Added to the database
# STORM - Scraping
# STORM - Added to the database
# STRONG - Scraping
# STRONG - Added to the database
# SUBC - Scraping
# SUBC - Added to the database
# TIL - Scraping
# TIL - Added to the database
# TEAM - Scraping
# TEAM - Added to the database
# TEL - Scraping
# TEL - Added to the database
# TGS - Scraping
# TGS - Added to the database
# SSC - Scraping
# SSC - Added to the database
# THIN - Scraping
# THIN - Added to the database
# TIDE - Scraping
# TIDE - Added to the database
# TOM - Scraping
# TOM - Added to the database
# TTS - Scraping
# TTS - Added to the database
# VARDIA - Scraping
# VARDIA - Added to the database
# VEI - Scraping
# VEI - Added to the database
# VISTIN - Scraping
# VISTIN - Not scraped, see comment
# VVL - Scraping
# VVL - Added to the database
# WEIFA - Scraping
# WEIFA - Added to the database
# WRL - Scraping
# WRL - Added to the database
# WBULK - Scraping
# WBULK - Added to the database
# WWASA - Scraping
# WWASA - Added to the database
# WWI - Scraping
# WWI - Added to the database
# WWIB - Scraping
# WWIB - Added to the database
# WILS - Scraping
# WILS - Added to the database
# XXL - Scraping
# XXL - Added to the database
# YAR - Scraping
# YAR - Added to the database
# ZAL - Scraping
# ZAL - Added to the database
# ZONC - Scraping
# ZONC - Not scraped, see comment

# %% [markdown]
# #####Test if our data saved correctly
# Just to make sure mongoDB was working as I thought it should, I extract a signle row from the database and load it into a pandas dataframe.

# %%
test_data = collectionStocks.find_one() #Find a single value in our mongoDB database and check it isn't empty
test = pd.DataFrame.from_dict([test_data]) #Load that data into a pandas dataframe
#print test.columns.values[2].encode(encoding='latin-1')

# %% [markdown]
# #####Finished
# We now have 5 years of OsloBors data for most of our ticker list saved into our database. The next step is to get a basic understanding of our data by doing some stock analysis.
